# %% [markdown]
# <a href="https://colab.research.google.com/github/Mijini1881/DL23/blob/main/DL/DLW02a0530.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌳 **Digital Literacy & English Education** (Week 02):

# %% [markdown]
# # Part I. Basic learning
#
# Keywords
#
# [1] Text-to-Speech **API**: gTTs (Google Text-to-Speech)

# %% [markdown]
# ---
# # 📗Topic [1]: API (Application Programming Interface)
# ---

# %% [markdown]
# ## Demo {gTTS}

# %%
#@markdown 🔄 [1] Making functions (sample): tts(text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = False) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %%
# [2] Try it yourself
tts('Sociolinguists generally find differences in language use that reflect socially assigned gender roles.One frequent finding is that when language variation in a community is stable, women use more of the standard forms associated with overt prestige and switch to prestige forms when paying more attention to their speech. And men not only use more non-standard forms than women but also claim to use even more of them than they actually do.Trudgill explained this by proposing the idea of covert prestige—a sort of linguistic ‘street credibility’ that men aim for to prove their masculinity.The second gender difference that often surfaces is that when change does occur, women use more of the incoming forms than men. Some sociolinguists suggest that women use overt prestige forms and adopt changes from above because of linguistic insecurity.But these differences may also reflect gender expectations that limit women’s ability to demonstrate toughness or the fact that women more often do the jobs that require standard speech, such as teacher or receptionist. And women may lead change simply because of their role as child caregivers.Some researchers have also noted gender differences in discourse, the way conversations are structured, especially in same-sex conversations. They have observed that women are more likely to use language to build and maintain relationships (a rapport style), while men are more likely to use language to communicate factual information (a report style).Gender differences in language persist, which suggests that we might use language to ‘perform’ gender more often than we use it to perform region or class. Men use male-associated language to ‘be a man’— more precisely, to be a stereotypical heterosexual man.Some recent Canadian research suggests that people who describe themselves as avoiding traditional sex roles also avoid the poles of traditional male or female pronunciations. Nowadays, we see a move toward a single inclusive form for both men and women: actor for everyone, chair rather than chairman, and flight attendant rather than stewardess.A first issue to keep in mind is that people who come together to engage in some shared activity are likely to develop shared language practices. A second issue to keep in mind is that all of these social categories intersect.It’s the combination of social forces that is played out in language use. What it means to be masculine may vary with ethnicity  what it means to be working class may vary with gender or ethnicity.')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# [😉Emoji collection](https://gist.github.com/rxaviers/7360908)

# %%
#@markdown 🐧 [3] Better way? (Using a pop-up window)
mytext = input("Type text to generate audio: ")

tts(mytext)

# %% [markdown]
# ## Expanding tts: ktts, etts, ftts

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), ftts('text')
# %%capture
# !pip install gTTS      # Installation
from gtts import gTTS  # Import
from IPython.display import Audio

#######################
def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")
#######################

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

#######################

def ftts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "fr",
                    slow = False)
  
  gtts_object.save("F-audio.mp3")
  return Audio("F-audio.mp3")

# %%
etts("Good morning!")

# %%
ktts("안녕하세요?")

# %%
ftts("Bon jour!")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Better way? Using dropbox selections

# %% [markdown]
# gTTS documentation: [Reference link](https://gtts.readthedocs.io/en/latest/module.html)

# %%
Language = "kr" #@param = ["en", "kr"]

mytext = input("Type text: ")
if Language == "en":
  etts(mytext)
  myaudio = "E-audio.mp3"
elif Language == "kr":
  ktts(mytext)
  myaudio = "K-audio.mp3"

Audio(myaudio)
# Out:
# Type text: 안녕하세요
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Task: Add French to the above code

# %% [markdown]
# # 📗 DIY
# Coding on Colab and save it to your github account

# %% [markdown]
# Installation, import libraries

# %%
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %% [markdown]
# Defining a function

# %%
def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %% [markdown]
# # ⏰ Todo:

# %% [markdown]
# Using Colab, create a code page using the gTTS API and post it on your Github account (file name: DLHW01.ipynb)

# %% [markdown]
# ---
# # Continue to [DLW02b](https://github.com/MK316/Spring2023/blob/main/DL/DLW02b.ipynb)
