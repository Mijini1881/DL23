# %% [markdown]
# <a href="https://colab.research.google.com/github/Mijini1881/DL23/blob/main/DL/DLW02a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌳 **Digital Literacy & English Education** (Week 02):

# %% [markdown]
# # Part I. Basic learning
#
# Keywords
#
# [1] Text-to-Speech **API**: gTTs (Google Text-to-Speech)

# %% [markdown]
# ---
# # 📗Topic [1]: API (Application Programming Interface)
# ---

# %% [markdown]
# ## Demo {gTTS}

# %%
#@markdown 🔄 [1] Making functions (sample): tts(text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %%
# [2] Try it yourself
tts('Hello students')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# [😉Emoji collection](https://gist.github.com/rxaviers/7360908)

# %%
#@markdown 🐧 [3] Better way? (Using a pop-up window)
mytext = input("Type text to generate audio: ")

tts(mytext)

# %% [markdown]
# ## Expanding tts: ktts, etts, ftts

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), ftts('text')
# %%capture
# !pip install gTTS      # Installation
from gtts import gTTS  # Import
from IPython.display import Audio

#######################
def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")
#######################

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

#######################

def ftts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "fr",
                    slow = False)
  
  gtts_object.save("F-audio.mp3")
  return Audio("F-audio.mp3")

# %%
etts("Kahoot is an interactive learning platform that allows teachers and students to create and participate in educational games, quizzes, and surveys. Here are some of the key advantages of using Kahoot. Firstly, Kahoot provides an engaging and fun way to learn and review material. The game-like format of Kahoot challenges students to actively participate in the learning process, increasing their motivation and enthusiasm for the subject matter. Secondly, Kahoot allows teachers and students to create and customize content according to their specific learning goals and objectives. Teachers can create quizzes, surveys, and games on any topic and tailor them to the needs of their students. Thirdly, Kahoot promotes interactive learning, allowing teachers to assess student understanding in real-time and provide immediate feedback. Students can also collaborate and compete with each other, further enhancing the learning experience. Fourthly, Kahoot is accessible from any device with an internet connection, making it easy for students to participate from anywhere, at any time. Lastly, Kahoot provides valuable data-driven insights that help teachers understand student performance and identify areas where they may need additional support. Overall, Kahoot is an effective tool for promoting interactive and engaging learning, customizing content, and providing data-driven insights that help improve student performance.")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ktts("안녕하세요?")

# %%
ftts("Bon jour!")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Better way? Using dropbox selections

# %% [markdown]
# gTTS documentation: [Reference link](https://gtts.readthedocs.io/en/latest/module.html)

# %%
Language = "kr" #@param = ["en", "kr"]

mytext = input("Type text: ")
if Language == "en":
  etts(mytext)
  myaudio = "E-audio.mp3"
elif Language == "kr":
  ktts(mytext)
  myaudio = "K-audio.mp3"

Audio(myaudio)
# Out:
# Type text: 안녕하세요
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Task: Add French to the above code

# %% [markdown]
# # 📗 DIY
# Coding on Colab and save it to your github account

# %% [markdown]
# Installation, import libraries

# %%
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %% [markdown]
# Defining a function

# %%
def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %% [markdown]
# # ⏰ Todo:

# %% [markdown]
# Using Colab, create a code page using the gTTS API and post it on your Github account (file name: DLHW01.ipynb)

# %% [markdown]
# ---
# # Continue to [DLW02b](https://github.com/MK316/Spring2023/blob/main/DL/DLW02b.ipynb)
